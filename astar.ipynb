# %% [markdown]
# <h2>What A* Search is</h2>
# <p>
# A* (A-Star) is an intelligent search method that finds the shortest path from start to goal by combining the actual cost traveled so far plus an estimated cost to reach the goal. It uses a heuristic function to guide the search toward the goal efficiently.
# </p>
#
# <h2>A* Search Steps (Simple)</h2>
# <p>
# I. Start from the initial location (start node).<br>
# II. Put the start node into a priority queue with f = g + h, where g = 0 (cost from start) and h = estimated cost to goal.<br>
# III. Remove the node with the lowest f value from the queue.<br>
# IV. Check if it is the goal. If yes, stop and return the path.<br>
# V. If it is not the goal, explore all its neighbors.<br>
# VI. For each neighbor, calculate g = current_g + edge_cost and h = heuristic(neighbor, goal). Then f = g + h.<br>
# VII. If neighbor is not visited or new g is better, add it to the queue with its f value.<br>
# VIII. Repeat steps III to VII until the goal is found.
# </p>

# %%
from graph import graph
import heapq

def heuristic(node, goal):
    heuristic_values = {
        "Physics Lab": 0,
        "Chemistry Lab": 2,
        "Biology Lab": 4,
        "Sports Center": 7,
        "LH04": 2,
        "LH03": 3,
        "LH02": 4,
        "LH01": 5,
        "Learning Area": 6,
        "CL04": 5,
        "CL03": 4,
        "CL02": 3,
        "CL01": 2,
        "Campus Center": 8,
        "Main Library": 7,
        "Admin Office": 6,
        "Café": 7,
        "Female Library": 8,
        "Digital Library": 9,
        "HR Office": 7,
        "Freshman Office": 6,
        "Staff Lounge": 5,
        "Male Lounge": 5,
        "Female Lounge": 6
    }
    return heuristic_values.get(node, 10)

def a_star(start, goal):
    open_set = [(0 + heuristic(start, goal), 0, start, [start])]
    visited = {}
    
    while open_set:
        f, g, node, path = heapq.heappop(open_set)
        
        if node == goal:
            return path, g
        
        if node in visited and visited[node] <= g:
            continue
        
        visited[node] = g
        
        for neighbor, cost in graph[node]:
            new_g = g + cost
            new_f = new_g + heuristic(neighbor, goal)
            new_path = path + [neighbor]
            heapq.heappush(open_set, (new_f, new_g, neighbor, new_path))
    
    return None, None

start = "Campus Center"
goal = "Physics Lab"

path, cost = a_star(start, goal)

print("START:", start)
print("GOAL :", goal)
print("----------------------")

if path:
    print("PATH FOUND:")
    print(" -> ".join(path))
    print("TOTAL COST:", cost)
    print("STEPS:", len(path) - 1)
else:
    print("No path found")
# Out:
# START: Campus Center
# GOAL : Physics Lab
# ----------------------
# PATH FOUND:
# Campus Center -> Learning Area -> LH01 -> LH02 -> LH03 -> LH04 -> Physics Lab
# TOTAL COST: 8
# STEPS: 6

# %%
import tkinter as tk
from tkinter import ttk, messagebox
import heapq
import time

from graph import graph

pos = {
    "Campus Center": (400, 30),
    "Main Library": (180, 120),
    "Admin Office": (350, 120),
    "Learning Area": (550, 120),
    "Café": (750, 120),
    "Female Library": (130, 220),
    "Digital Library": (260, 220),
    "HR Office": (370, 220),
    "Freshman Office": (470, 220),
    "Staff Lounge": (560, 220),
    "LH01": (640, 220),
    "CL01": (720, 220),
    "Male Lounge": (810, 220),
    "LH02": (640, 320),
    "LH03": (640, 400),
    "LH04": (640, 480),
    "Physics Lab": (640, 560),
    "Chemistry Lab": (640, 620),
    "Biology Lab": (640, 680),
    "Sports Center": (640, 740),
    "CL02": (720, 320),
    "CL03": (720, 400),
    "CL04": (720, 480),
    "Female Lounge": (900, 220)
}

def heuristic(node, goal):
    heuristic_values = {
        "Physics Lab": 0,
        "Chemistry Lab": 2,
        "Biology Lab": 4,
        "Sports Center": 7,
        "LH04": 2,
        "LH03": 3,
        "LH02": 4,
        "LH01": 5,
        "Learning Area": 6,
        "CL04": 5,
        "CL03": 4,
        "CL02": 3,
        "CL01": 2,
        "Campus Center": 8,
        "Main Library": 7,
        "Admin Office": 6,
        "Café": 7,
        "Female Library": 8,
        "Digital Library": 9,
        "HR Office": 7,
        "Freshman Office": 6,
        "Staff Lounge": 5,
        "Male Lounge": 5,
        "Female Lounge": 6
    }
    return heuristic_values.get(node, 10)

def calculate_path_cost(path):
    total = 0
    for i in range(len(path) - 1):
        for neighbor, cost in graph[path[i]]:
            if neighbor == path[i + 1]:
                total += cost
                break
    return total

def a_star_search(start, goal, callback=None):
    open_set = [(0 + heuristic(start, goal), 0, start, [start])]
    visited = {}
    
    while open_set:
        f, g, node, path = heapq.heappop(open_set)
        
        if callback:
            callback(node, "exploring", g, heuristic(node, goal))
            time.sleep(0.3)
        
        if node == goal:
            if callback:
                for i, p in enumerate(path):
                    current_cost = calculate_path_cost(path[:i+1])
                    callback(p, "final", current_cost, heuristic(p, goal))
                    time.sleep(0.15)
            return path, g
        
        if node in visited and visited[node] <= g:
            continue
        
        visited[node] = g
        
        for neighbor, cost in graph[node]:
            new_g = g + cost
            new_f = new_g + heuristic(neighbor, goal)
            new_path = path + [neighbor]
            heapq.heappush(open_set, (new_f, new_g, neighbor, new_path))
            
            if callback:
                callback(neighbor, "queued", new_g, heuristic(neighbor, goal))
                time.sleep(0.1)
    
    return None, None

class AStarVisualization:
    def __init__(self, root):
        self.root = root
        self.root.title("A* SEARCH - Campus Navigation")
        self.root.geometry("1200x800")
        self.root.configure(bg="#0a0a1a")
        
        main_frame = tk.Frame(root, bg="#0a0a1a")
        main_frame.pack(fill=tk.BOTH, expand=True)
        
        self.canvas = tk.Canvas(main_frame, width=900, height=780, bg="#0f0f1a", highlightthickness=0)
        self.canvas.pack(side=tk.LEFT, fill=tk.BOTH, expand=True, padx=10, pady=10)
        
        control_frame = tk.Frame(main_frame, bg="#1a1a2e", width=280)
        control_frame.pack(side=tk.RIGHT, fill=tk.Y, padx=5, pady=10)
        control_frame.pack_propagate(False)
        
        title = tk.Label(control_frame, text="A* SEARCH", font=("Arial", 16, "bold"), bg="#1a1a2e", fg="#e94560")
        title.pack(pady=15)
        
        desc = tk.Label(control_frame, text="f(n) = g(n) + h(n)", font=("Arial", 10, "bold"), bg="#1a1a2e", fg="#ffd700")
        desc.pack(pady=5)
        
        desc2 = tk.Label(control_frame, text="g(n)=actual cost | h(n)=heuristic", font=("Arial", 8), bg="#1a1a2e", fg="#aaaaaa")
        desc2.pack(pady=2)
        
        start_frame = tk.Frame(control_frame, bg="#1a1a2e")
        start_frame.pack(pady=10, fill=tk.X, padx=20)
        
        tk.Label(start_frame, text="START:", font=("Arial", 11, "bold"), bg="#1a1a2e", fg="#00ff88").pack(anchor=tk.W)
        self.start_var = tk.StringVar(value="Campus Center")
        self.start_combo = ttk.Combobox(start_frame, textvariable=self.start_var, values=list(pos.keys()), font=("Arial", 10))
        self.start_combo.pack(fill=tk.X, pady=5)
        
        goal_frame = tk.Frame(control_frame, bg="#1a1a2e")
        goal_frame.pack(pady=10, fill=tk.X, padx=20)
        
        tk.Label(goal_frame, text="GOAL:", font=("Arial", 11, "bold"), bg="#1a1a2e", fg="#e94560").pack(anchor=tk.W)
        self.goal_var = tk.StringVar(value="Physics Lab")
        self.goal_combo = ttk.Combobox(goal_frame, textvariable=self.goal_var, values=list(pos.keys()), font=("Arial", 10))
        self.goal_combo.pack(fill=tk.X, pady=5)
        
        self.run_button = tk.Button(control_frame, text="RUN A* SEARCH", font=("Arial", 11, "bold"), bg="#e94560", fg="white", command=self.run_search)
        self.run_button.pack(pady=15, padx=20, fill=tk.X)
        
        self.reset_button = tk.Button(control_frame, text="RESET", font=("Arial", 10), bg="#5c5c8a", fg="white", command=self.reset_canvas)
        self.reset_button.pack(pady=5, padx=20, fill=tk.X)
        
        info_frame = tk.Frame(control_frame, bg="#0f0f1a", relief=tk.RAISED, bd=2)
        info_frame.pack(pady=15, padx=20, fill=tk.X)
        
        self.cost_label = tk.Label(info_frame, text="TOTAL COST: --", font=("Arial", 11, "bold"), bg="#0f0f1a", fg="#ffd700")
        self.cost_label.pack(pady=5)
        
        self.steps_label = tk.Label(info_frame, text="STEPS: --", font=("Arial", 11), bg="#0f0f1a", fg="#ffffff")
        self.steps_label.pack(pady=5)
        
        self.f_value_label = tk.Label(info_frame, text="f(n) = --", font=("Arial", 10), bg="#0f0f1a", fg="#88aaff")
        self.f_value_label.pack(pady=3)
        
        path_frame = tk.Frame(control_frame, bg="#1a1a2e")
        path_frame.pack(pady=10, padx=20, fill=tk.BOTH, expand=True)
        
        tk.Label(path_frame, text="PATH FOUND:", font=("Arial", 10, "bold"), bg="#1a1a2e", fg="#00ff88").pack(anchor=tk.W)
        
        self.path_text = tk.Text(path_frame, height=18, width=30, bg="#0f0f1a", fg="#e0e0ff", font=("Arial", 9), wrap=tk.WORD)
        self.path_text.pack(fill=tk.BOTH, expand=True, pady=5)
        
        self.draw_graph()
    
    def draw_graph(self):
        self.canvas.delete("all")
        for node in graph:
            if node not in pos:
                continue
            x, y = pos[node]
            text_width = len(node) * 7
            rect_x1 = x - text_width//2 - 10
            rect_x2 = x + text_width//2 + 10
            rect_y1 = y - 18
            rect_y2 = y + 18
            
            self.canvas.create_rectangle(rect_x1, rect_y1, rect_x2, rect_y2, fill="#2d2d44", outline="#5c5c8a", width=2, tags=f"node_{node}")
            self.canvas.create_text(x, y - 5, text=node, font=("Arial", 7, "bold"), fill="#e0e0ff", tags=f"text_{node}")
            
            h_val = heuristic(node, "Physics Lab")
            self.canvas.create_text(x, y + 8, text=f"h={h_val}", font=("Arial", 6), fill="#ffd700", tags=f"heuristic_{node}")
            
            for neighbor, weight in graph[node]:
                if neighbor in pos:
                    nx, ny = pos[neighbor]
                    self.canvas.create_line(x, y, nx, ny, fill="#3d3d5c", width=2)
                    mid_x, mid_y = (x + nx)//2, (y + ny)//2
                    self.canvas.create_text(mid_x, mid_y - 5, text=str(weight), font=("Arial", 8), fill="#ffd700", tags=f"weight_{node}_{neighbor}")
    
    def reset_canvas(self):
        self.draw_graph()
        self.cost_label.config(text="TOTAL COST: --")
        self.steps_label.config(text="STEPS: --")
        self.f_value_label.config(text="f(n) = --")
        self.path_text.delete(1.0, tk.END)
        self.run_button.config(state=tk.NORMAL, text="RUN A* SEARCH")
    
    def update_node_with_f(self, node, color, g_cost, h_cost):
        if node not in pos:
            return
        x, y = pos[node]
        text_width = len(node) * 7
        rect_x1 = x - text_width//2 - 10
        rect_x2 = x + text_width//2 + 10
        rect_y1 = y - 18
        rect_y2 = y + 18
        
        self.canvas.delete(f"node_{node}")
        self.canvas.create_rectangle(rect_x1, rect_y1, rect_x2, rect_y2, fill=color, outline="#7a7aaa", width=2, tags=f"node_{node}")
        self.canvas.create_text(x, y - 5, text=node, font=("Arial", 7, "bold"), fill="#ffffff", tags=f"text_{node}")
        
        h_val = heuristic(node, self.goal_var.get())
        f_val = g_cost + h_val
        self.canvas.create_text(x, y + 8, text=f"g={g_cost} h={h_val}", font=("Arial", 5), fill="#ffd700", tags=f"heuristic_{node}")
        
        self.root.update()
    
    def animate_smooth_path(self, path, total_cost):
        steps = len(path)
        time_per_node = 2.5 / steps
        
        for idx, node in enumerate(path):
            current_cost = calculate_path_cost(path[:idx+1])
            h_val = heuristic(node, self.goal_var.get())
            
            x, y = pos[node]
            text_width = len(node) * 7
            rect_x1 = x - text_width//2 - 10
            rect_x2 = x + text_width//2 + 10
            rect_y1 = y - 18
            rect_y2 = y + 18
            
            for i in range(15):
                alpha = i / 15
                if i < 8:
                    r, g, b = 50, 50, 100
                else:
                    r, g, b = 0, 255, 68
                
                color = f'#{int(r + (0 - r) * alpha):02x}{int(g + (255 - g) * alpha):02x}{int(b + (68 - b) * alpha):02x}'
                
                self.canvas.delete(f"node_{node}")
                self.canvas.create_rectangle(rect_x1, rect_y1, rect_x2, rect_y2, fill=color, outline="#7a7aaa", width=2, tags=f"node_{node}")
                self.canvas.create_text(x, y - 5, text=node, font=("Arial", 7, "bold"), fill="#ffffff", tags=f"text_{node}")
                self.canvas.create_text(x, y + 8, text=f"g={current_cost} h={h_val}", font=("Arial", 5), fill="#ffd700", tags=f"heuristic_{node}")
                self.root.update()
                time.sleep(time_per_node / 15)
            
            self.cost_label.config(text=f"TOTAL COST: {current_cost}")
            self.f_value_label.config(text=f"f(n) = {current_cost} + {h_val} = {current_cost + h_val}")
            self.root.update()
        
        for node in path:
            x, y = pos[node]
            text_width = len(node) * 7
            rect_x1 = x - text_width//2 - 10
            rect_x2 = x + text_width//2 + 10
            rect_y1 = y - 18
            rect_y2 = y + 18
            self.canvas.delete(f"node_{node}")
            self.canvas.create_rectangle(rect_x1, rect_y1, rect_x2, rect_y2, fill="#00ff44", outline="#7a7aaa", width=2, tags=f"node_{node}")
            self.canvas.create_text(x, y - 5, text=node, font=("Arial", 7, "bold"), fill="#000000", tags=f"text_{node}")
            self.root.update()
            time.sleep(0.08)
        
        self.cost_label.config(text=f"TOTAL COST: {total_cost}")
    
    def display_path(self, path, cost):
        self.path_text.delete(1.0, tk.END)
        running_cost = 0
        for i, node in enumerate(path):
            if i > 0:
                for neighbor, c in graph[path[i-1]]:
                    if neighbor == node:
                        running_cost += c
                        break
            
            h_val = heuristic(node, self.goal_var.get())
            f_val = running_cost + h_val
            
            if i == 0:
                self.path_text.insert(tk.END, f"START: {node}\n")
                self.path_text.insert(tk.END, f"       g=0, h={h_val}, f={f_val}\n\n")
            elif i == len(path) - 1:
                self.path_text.insert(tk.END, f"GOAL: {node}\n")
                self.path_text.insert(tk.END, f"       g={running_cost}, h={h_val}, f={f_val}\n")
                self.path_text.insert(tk.END, f"\nTOTAL COST: {running_cost}\n")
            else:
                self.path_text.insert(tk.END, f"{node}\n")
                self.path_text.insert(tk.END, f"       g={running_cost}, h={h_val}, f={f_val}\n\n")
        
        self.cost_label.config(text=f"TOTAL COST: {cost}")
        self.steps_label.config(text=f"STEPS: {len(path) - 1}")
    
    def search_callback(self, node, status, g_cost, h_cost):
        if status == "exploring":
            self.update_node_with_f(node, "#ffaa44", g_cost, h_cost)
            f_val = g_cost + h_cost
            self.f_value_label.config(text=f"f({node}) = {g_cost} + {h_cost} = {f_val}")
            time.sleep(0.25)
        elif status == "queued":
            self.update_node_with_f(node, "#88aaff", g_cost, h_cost)
            time.sleep(0.1)
        elif status == "final":
            self.update_node_with_f(node, "#00ff44", g_cost, h_cost)
            f_val = g_cost + h_cost
            self.f_value_label.config(text=f"f({node}) = {g_cost} + {h_cost} = {f_val}")
            time.sleep(0.12)
    
    def run_search(self):
        self.reset_canvas()
        self.run_button.config(state=tk.DISABLED, text="SEARCHING...")
        
        start = self.start_var.get()
        goal = self.goal_var.get()
        
        if start not in graph or goal not in graph:
            messagebox.showerror("Error", "Invalid location!")
            self.run_button.config(state=tk.NORMAL, text="RUN A* SEARCH")
            return
        
        self.root.update()
        
        path, cost = a_star_search(start, goal, self.search_callback)
        
        if path:
            self.display_path(path, cost)
            self.animate_smooth_path(path, cost)
            self.run_button.config(state=tk.NORMAL, text="RUN A* SEARCH")
        else:
            self.path_text.delete(1.0, tk.END)
            self.path_text.insert(tk.END, f"NO PATH FOUND\n")
            self.path_text.insert(tk.END, f"From '{start}' to '{goal}'")
            self.run_button.config(state=tk.NORMAL, text="RUN A* SEARCH")

if __name__ == "__main__":
    root = tk.Tk()
    app = AStarVisualization(root)
    root.mainloop()
